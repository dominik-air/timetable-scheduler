# %%
import json

with open(f'statistics/operators_tests.json', 'r') as file:
    data = json.load(file)

# %%
list(data.keys())[0]
# Out:
# '(0.1, 0.1, 0.8)'

# %%
list(data.values())[0][0]['initial_cost']
# Out:
# 2408.0

# %%
pandas_data = {'probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation)': [], 'runtime': [], 'cost function change': []}
for key, values in data.items():
    for value in values:
        pandas_data['probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation)'].append(key)
        pandas_data['runtime'].append(value['elapsed_time'])
        pandas_data['cost function change'].append(value['initial_cost'] - value['best_cost'])

# %%
import pandas as pd

df = pd.DataFrame(pandas_data)
df.head()
# Out:
#   probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation)  \
# 0                                    (0.1, 0.1, 0.8)
# 1                                    (0.1, 0.1, 0.8)
# 2                                    (0.1, 0.1, 0.8)
# 3                                    (0.1, 0.1, 0.8)
# 4                                    (0.1, 0.1, 0.8)
#
#     runtime  cost function change
# 0  4.253448                 800.8
# 1  4.950752                 461.4
# 2  4.377183                 600.4
# 3  4.973605                 663.8
# 4  4.698864                1075.6

# %%
df['probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation)'].value_counts()
# Out:
# (0.25, 0.3, 0.45)    30
# (0.1, 0.1, 0.8)      30
# (0.15, 0.3, 0.55)    30
# (0.1, 0.2, 0.7)      30
# (0.3, 0.15, 0.55)    30
# (0.2, 0.1, 0.7)      30
# (0.15, 0.2, 0.65)    30
# Name: probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation), dtype: int64

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(15.7,8.27)})
sns.boxplot(x='probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation)', y='cost function change', data=df, showfliers=False).set_title(
    "Wykres wartości funkcji kosztu od prawdopodobieństw operatorów generowania sąsiedztwa")
# Out:
# Text(0.5, 1.0, 'Wykres wartości funkcji kosztu od prawdopodobieństw operatorów generowania sąsiedztwa')

# %%
sns.boxplot(x='probabilities (matrix_transposition, matrix_inner_translation, matrix_cut_and_paste_translation)', y='runtime', data=df, showfliers=False).set_title(
    "Wykres czasu wyznaczania rozwiązania końcowego od prawdopodobieństw operatorów generowania sąsiedztwa")
# Out:
# Text(0.5, 1.0, 'Wykres czasu wyznaczania rozwiązania końcowego od prawdopodobieństw operatorów generowania sąsiedztwa')
