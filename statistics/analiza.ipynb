# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

with open('init_solutions.txt', 'r') as f:
    data = [float(i) for i in f.readline().split(',')]

df = pd.DataFrame(data)
sns.histplot(data=df)
plt.xlabel('wartość funkcji celu')
plt.ylabel('ilość wystąpień')
plt.title('Rozkład wartości funkcji celu rozwiązania początkowego')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(len(df))
# Out:
# 998

# %% [markdown]
# Testy przeprowadzono 1000 razy, zatem 2 razy na 1000 zdarzyło się, że algorytm nie był w stanie zbudować dopuszczalne rozwiązanie początkowe.

# %%
with open('wyniki_sa.txt', 'r') as f:
    data = [float(i) for i in f.readline().split(',')]

plt.plot(data)
plt.show()

# %%
with open('wyniki_sa_1.txt', 'r') as f:
    data = [float(i) for i in f.readline().split(',')]

plt.plot(data)
plt.show()
